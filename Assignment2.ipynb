# %% [markdown]
# <a href="https://colab.research.google.com/github/corrielynnyuill-debug/colab-git-assignment2-cly/blob/main/Assignment2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Git and GitHub Assignment 2
#
# This notebook demonstrates basic Git operations.

# %%
def multiply_numbers(a, b):
  return a * b

print(multiply_numbers(10, 4))
print(multiply_numbers(5, 9))
print(multiply_numbers(7, 8))
# Out:
# 40
# 45
# 56

# %%
# !git config --global user.email "corrie.lynn.yuill@gmail.com"
# !git config --global user.name "corrielynnyuill-debug"
print("Git configured successfully")

# !git clone https://github.com/corrielynnyuill-debug/colab-git-assignment2-cly.git
# %cd colab-git-assignment2-cly
# !git checkout -b assignment2-branch
# !ls
# Out:
# Git configured successfully
# Cloning into 'colab-git-assignment2-cly'...
# remote: Enumerating objects: 9, done.
# remote: Counting objects: 100% (9/9), done.
# remote: Compressing objects: 100% (8/8), done.
# remote: Total 9 (delta 1), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (9/9), done.
# Resolving deltas: 100% (1/1), done.
# /content/colab-git-assignment2-cly/colab-git-assignment2-cly
# Switched to a new branch 'assignment2-branch'
# Assignment2.ipynb  README.md

# %%
# Add and commit notebook to repository
# !git add Assignment2.ipynb
# !git commit -m "Added notebook with muliplication function to repository"

# Push changes to GitHub
# !git remote add origin https://github.com/corrielynnyuill-debug/colab-git-assignment2-cly.git
# !git push --set-upstream origin assignment2-branch
# Out:
# On branch assignment2-branch
# nothing to commit, working tree clean
# fatal: could not read Username for 'https://github.com': No such device or address

# %%
def divide_numbers(a, b):
  if b != 0:
    return a/b
  else:
    return "Cannot divide by zero"

print(divide_numbers(14, 2))
print(divide_numbers(75, 3))
print(divide_numbers(10, 0))
# Out:
# 7.0
# 25.0
# Cannot divide by zero

# %%
# Add and commit division function
# !git add Assignment2.ipynb
# !git commit -m "Add division function"

# Push changes to GitHub
# !git push --set-upstream origin assignment2-branch
# Out:
# On branch assignment2-branch
# nothing to commit, working tree clean
# fatal: could not read Username for 'https://github.com': No such device or address
