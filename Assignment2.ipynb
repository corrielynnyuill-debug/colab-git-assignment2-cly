# %% [markdown]
# <a href="https://colab.research.google.com/github/corrielynnyuill-debug/colab-git-assignment2-cly/blob/main/Assignment2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Git and GitHub Assignment 2
#
# This notebook demonstrates basic Git operations.

# %%
def multiply_numbers(a, b):
  return a * b

print(multiply_numbers(3, 4))
print(multiply_numbers(5, 6))
print(multiply_numbers(7, 8))
# Out:
# 12
# 30
# 56

# %%
def divide_numbers(a, b):
  if b != 0:
    return a/b
  else:
    return "Cannot divide by zero"

print(divide_numbers(10, 2))
print(divide_numbers(15, 3))
print(divide_numbers(1, 0))
# Out:
# 5.0
# 5.0
# Cannot divide by zero
